# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
aerolinea = pd.read_csv('C:\\Users\\ALLAN\\Desktop\\Business Analitics con Python y ChatGPT\\AirPassengers.csv', index_col = 'Month')

# %%
aerolinea
# Out:
#          #Passengers
# Month
# 1949-01          112
# 1949-02          118
# 1949-03          132
# 1949-04          129
# 1949-05          121
# ...              ...
# 1960-08          606
# 1960-09          508
# 1960-10          461
# 1960-11          390
# 1960-12          432
#
# [144 rows x 1 columns]

# %%
aerolinea = aerolinea.rename(columns={'#Passengers' : 'Passengers'})

# %%
aerolinea
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
aerolinea.dropna(inplace = True)

# %%
aerolinea.index
# Out:
# Index(['1949-01', '1949-02', '1949-03', '1949-04', '1949-05', '1949-06',
#        '1949-07', '1949-08', '1949-09', '1949-10',
#        ...
#        '1960-03', '1960-04', '1960-05', '1960-06', '1960-07', '1960-08',
#        '1960-09', '1960-10', '1960-11', '1960-12'],
#       dtype='object', name='Month', length=144)

# %%
aerolinea.index = pd.to_datetime(aerolinea.index)

# %%
aerolinea.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
aerolinea['PMS6meses'] = aerolinea['Passengers'].rolling(window=6).mean()

# %%
aerolinea
# Out:
#             Passengers   PMS6meses
# Month
# 1949-01-01         112         NaN
# 1949-02-01         118         NaN
# 1949-03-01         132         NaN
# 1949-04-01         129         NaN
# 1949-05-01         121         NaN
# ...                ...         ...
# 1960-08-01         606  519.166667
# 1960-09-01         508  534.000000
# 1960-10-01         461  534.000000
# 1960-11-01         390  520.333333
# 1960-12-01         432  503.166667
#
# [144 rows x 2 columns]

# %%
aerolinea['PMS12meses'] = aerolinea['Passengers'].rolling(window=12).mean()

# %%
aerolinea
# Out:
#             Passengers   PMS6meses  PMS12meses
# Month
# 1949-01-01         112         NaN         NaN
# 1949-02-01         118         NaN         NaN
# 1949-03-01         132         NaN         NaN
# 1949-04-01         129         NaN         NaN
# 1949-05-01         121         NaN         NaN
# ...                ...         ...         ...
# 1960-08-01         606  519.166667  463.333333
# 1960-09-01         508  534.000000  467.083333
# 1960-10-01         461  534.000000  471.583333
# 1960-11-01         390  520.333333  473.916667
# 1960-12-01         432  503.166667  476.166667
#
# [144 rows x 3 columns]

# %%
aerolinea.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
aerolinea['MME12'] = aerolinea['Passengers'].ewm(span=12).mean()

# %%
aerolinea
# Out:
#             Passengers   PMS6meses  PMS12meses       MME12
# Month
# 1949-01-01         112         NaN         NaN  112.000000
# 1949-02-01         118         NaN         NaN  115.250000
# 1949-03-01         132         NaN         NaN  121.787529
# 1949-04-01         129         NaN         NaN  124.064224
# 1949-05-01         121         NaN         NaN  123.231685
# ...                ...         ...         ...         ...
# 1960-08-01         606  519.166667  463.333333  494.898620
# 1960-09-01         508  534.000000  467.083333  496.914217
# 1960-10-01         461  534.000000  471.583333  491.388952
# 1960-11-01         390  520.333333  473.916667  475.790652
# 1960-12-01         432  503.166667  476.166667  469.053629
#
# [144 rows x 4 columns]

# %%
aerolinea[['Passengers','MME12']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
aerolinea['MME6'] = aerolinea['Passengers'].ewm(span=6).mean()

# %%
aerolinea
# Out:
#             Passengers   PMS6meses  PMS12meses       MME12        MME6
# Month
# 1949-01-01         112         NaN         NaN  112.000000  112.000000
# 1949-02-01         118         NaN         NaN  115.250000  115.500000
# 1949-03-01         132         NaN         NaN  121.787529  122.917431
# 1949-04-01         129         NaN         NaN  124.064224  125.266892
# 1949-05-01         121         NaN         NaN  123.231685  123.769332
# ...                ...         ...         ...         ...         ...
# 1960-08-01         606  519.166667  463.333333  494.898620  538.549357
# 1960-09-01         508  534.000000  467.083333  496.914217  529.820969
# 1960-10-01         461  534.000000  471.583333  491.388952  510.157835
# 1960-11-01         390  520.333333  473.916667  475.790652  475.827025
# 1960-12-01         432  503.166667  476.166667  469.053629  463.305018
#
# [144 rows x 5 columns]

# %%
aerolinea[['Passengers','MME6','MME12']].plot()
# Out:
# <Axes: xlabel='Month'>
